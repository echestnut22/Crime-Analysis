# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', None)

# %%
police_df_cleaned = pd.read_csv('/Users/Emi/Documents/GitHub/Crime-Analysis/police_df_cleaned.csv')
crime_df = pd.read_csv('Chicago_Crime_Data_Cleaned.csv')

# %%
crime_df.head()
# Out:
#          ID Case Number                 Date                 Block  IUCR  \
# 0   5741943    HN549294  2007-08-25 09:22:18    074XX N ROGERS AVE  0560
# 1   1930689    HH109118  2002-01-05 21:24:00        007XX E 103 ST  0820
# 2  13203321    JG415333  2023-09-06 17:00:00      002XX N Wells st  1320
# 3  13210088    JG423627  2023-08-31 12:00:00  023XX W JACKSON BLVD  1153
# 4  13210004    JG422532  2023-07-24 21:45:00  073XX S JEFFERY BLVD  0281
#
#               Primary Type                          Description  \
# 0                  ASSAULT                               SIMPLE
# 1                    THEFT                       $500 AND UNDER
# 2          CRIMINAL DAMAGE                           TO VEHICLE
# 3       DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 4  CRIMINAL SEXUAL ASSAULT                       NON-AGGRAVATED
#
#                      Location Description  Arrest  Domestic  Beat  District  \
# 0                                   OTHER   False     False  2422      24.0
# 1                             GAS STATION    True     False   512       5.0
# 2  PARKING LOT / GARAGE (NON RESIDENTIAL)   False     False   122       1.0
# 3                                  STREET   False     False  1225      12.0
# 4                               APARTMENT   False     False   333       3.0
#
#    Ward  Community Area FBI Code  X Coordinate  Y Coordinate  Year  \
# 0  49.0             1.0      08A           NaN           NaN  2007
# 1   NaN             NaN       06           NaN           NaN  2002
# 2  42.0            32.0       14     1174694.0     1901831.0  2023
# 3  27.0            28.0       11     1160870.0     1898642.0  2023
# 4   7.0            43.0       02     1190812.0     1856743.0  2023
#
#             Updated On   Latitude  Longitude                       Location  \
# 0  2015-08-17 15:03:40        NaN        NaN                            NaN
# 1  2016-02-04 06:33:39        NaN        NaN                            NaN
# 2  2023-11-04 15:40:18  41.886018 -87.633938  (41.886018055, -87.633937881)
# 3  2023-09-16 15:41:56  41.877565 -87.684791   (41.877565108, -87.68479102)
# 4  2023-09-16 15:41:56  41.761919 -87.576209    (41.7619185, -87.576209245)
#
#    Historical Wards 2003-2015  Zip Codes  Community Areas  Census Tracts  \
# 0                         NaN        NaN              NaN            NaN
# 1                         NaN        NaN              NaN            NaN
# 2                        22.0    14309.0             38.0           92.0
# 3                        48.0    21184.0             29.0          766.0
# 4                        32.0    22538.0             39.0          419.0
#
#    Wards  Boundaries - ZIP Codes  Police Districts  Police Beats  \
# 0    NaN                     NaN               NaN           NaN
# 1    NaN                     NaN               NaN           NaN
# 2   36.0                    46.0              22.0          79.0
# 3   46.0                    28.0              15.0         139.0
# 4   37.0                    24.0              18.0          89.0
#
#    Primary Type Grouping
# 0  All Other Crime Types
# 1  All Other Crime Types
# 2  All Other Crime Types
# 3  All Other Crime Types
# 4  All Other Crime Types

# %%
#Keeping only overall safety and trust scores to start, we can add more later if necessary
police_df_filtered = police_df_cleaned[['DISTRICT','SAFETY','TRUST','START_DATE','END_DATE']]

# %%
crime_df.District = crime_df.District.astype('str')
len(list(crime_df.District.unique()))
# Out:
# 25

# %%
police_df_filtered.DISTRICT = police_df_filtered.DISTRICT.astype('str')
len(list(police_df_filtered.DISTRICT.unique()))
# Out:
# /var/folders/1s/stcy42l14bd01cnvp2y2xhzr0000gn/T/ipykernel_4420/3451442942.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   police_df_filtered.DISTRICT = police_df_filtered.DISTRICT.astype('str')
# 22

# %%
police_df_filtered['START_DATE'] = pd.to_datetime(police_df_filtered['START_DATE'])
police_df_filtered['END_DATE'] = pd.to_datetime(police_df_filtered['END_DATE'])
# Out:
# /var/folders/1s/stcy42l14bd01cnvp2y2xhzr0000gn/T/ipykernel_4420/2084439707.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   police_df_filtered['START_DATE'] = pd.to_datetime(police_df_filtered['START_DATE'])
# /var/folders/1s/stcy42l14bd01cnvp2y2xhzr0000gn/T/ipykernel_4420/2084439707.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   police_df_filtered['END_DATE'] = pd.to_datetime(police_df_filtered['END_DATE'])

# %%
(police_df_filtered['END_DATE'] - police_df_filtered['START_DATE']).dt.days.value_counts()
#These all seem to show a time period of one month, so we can just create columns for the Month and Year
# Out:
# 30    3731
# 29    2184
# 27     455
# 28      91
# dtype: int64

# %%
police_df_filtered['Year_Month'] = police_df_filtered['START_DATE'].dt.to_period('M')
# Out:
# /var/folders/1s/stcy42l14bd01cnvp2y2xhzr0000gn/T/ipykernel_4420/1937159896.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   police_df_filtered['Year_Month'] = police_df_filtered['START_DATE'].dt.to_period('M')

# %%
police_df_filtered.drop(columns=['START_DATE','END_DATE'])
# Out:
#      DISTRICT  SAFETY  TRUST Year_Month
# 0        14.0   56.69  60.90    2021-04
# 1         5.0   35.51  47.52    2021-04
# 2        11.0   42.63  46.38    2021-04
# 3         9.0   46.02  63.57    2021-04
# 4        16.0   55.97  79.77    2021-04
# ...       ...     ...    ...        ...
# 6456     12.0   66.53  63.30    2023-09
# 6457      1.0   69.07  73.06    2023-09
# 6458     16.0   65.99  71.75    2023-09
# 6459     10.0   57.74  54.83    2023-09
# 6460     10.0   57.34  50.63    2023-09
#
# [6461 rows x 4 columns]

# %%
police_df_filtered.head()
# Out:
#   DISTRICT  SAFETY  TRUST START_DATE   END_DATE Year_Month
# 0     14.0   56.69  60.90 2021-04-01 2021-04-30    2021-04
# 1      5.0   35.51  47.52 2021-04-01 2021-04-30    2021-04
# 2     11.0   42.63  46.38 2021-04-01 2021-04-30    2021-04
# 3      9.0   46.02  63.57 2021-04-01 2021-04-30    2021-04
# 4     16.0   55.97  79.77 2021-04-01 2021-04-30    2021-04

# %% [markdown]
# There are multiple safety and trust scores for each district since we removed sectors, so we can take the average scores for each district

# %%
mean_sentiment_scores = police_df_filtered.groupby(['DISTRICT','Year_Month'])['SAFETY','TRUST'].mean().round(2).reset_index()
# Out:
# /var/folders/1s/stcy42l14bd01cnvp2y2xhzr0000gn/T/ipykernel_4420/4264651156.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   
# 0      1.0    2017-11   62.55  64.38
# 1      1.0    2017-12   63.03  63.73
# 2      1.0    2018-01   68.74  65.46
# 3      1.0    2018-02   73.82  66.11
# 4      1.0    2018-03   71.74  67.13

# %%
crime_df['Date'] = pd.to_datetime(crime_df['Date'])

# %%
crime_df['Year_Month'] = crime_df['Date'].dt.to_period('M')

# %%
mean_sentiment_scores.rename(columns={'SAFETY':'Police Safety Score',
                                      'TRUST':'Police Trust Score',
                                      'DISTRICT':'Police Districts'},inplace=True)

# %%
crime_df['Police Districts'] = crime_df['Police Districts'].astype('str')

# %%
crime_and_police = pd.merge(crime_df,mean_sentiment_scores,how='left',on=['Police Districts','Year_Month'])
crime_and_police.head(5)
# Out:
#          ID Case Number                Date                 Block  IUCR  \
# 0   5741943    HN549294 2007-08-25 09:22:18    074XX N ROGERS AVE  0560
# 1   1930689    HH109118 2002-01-05 21:24:00        007XX E 103 ST  0820
# 2  13203321    JG415333 2023-09-06 17:00:00      002XX N Wells st  1320
# 3  13210088    JG423627 2023-08-31 12:00:00  023XX W JACKSON BLVD  1153
# 4  13210004    JG422532 2023-07-24 21:45:00  073XX S JEFFERY BLVD  0281
#
#               Primary Type                          Description  \
# 0                  ASSAULT                               SIMPLE
# 1                    THEFT                       $500 AND UNDER
# 2          CRIMINAL DAMAGE                           TO VEHICLE
# 3       DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 4  CRIMINAL SEXUAL ASSAULT                       NON-AGGRAVATED
#
#                      Location Description  Arrest  Domestic  Beat District  \
# 0                                   OTHER   False     False  2422     24.0
# 1                             GAS STATION    True     False   512      5.0
# 2  PARKING LOT / GARAGE (NON RESIDENTIAL)   False     False   122      1.0
# 3                                  STREET   False     False  1225     12.0
# 4                               APARTMENT   False     False   333      3.0
#
#    Ward  Community Area FBI Code  X Coordinate  Y Coordinate  Year  \
# 0  49.0             1.0      08A           NaN           NaN  2007
# 1   NaN             NaN       06           NaN           NaN  2002
# 2  42.0            32.0       14     1174694.0     1901831.0  2023
# 3  27.0            28.0       11     1160870.0     1898642.0  2023
# 4   7.0            43.0       02     1190812.0     1856743.0  2023
#
#             Updated On   Latitude  Longitude                       Location  \
# 0  2015-08-17 15:03:40        NaN        NaN                            NaN
# 1  2016-02-04 06:33:39        NaN        NaN                            NaN
# 2  2023-11-04 15:40:18  41.886018 -87.633938  (41.886018055, -87.633937881)
# 3  2023-09-16 15:41:56  41.877565 -87.684791   (41.877565108, -87.68479102)
# 4  2023-09-16 15:41:56  41.761919 -87.576209    (41.7619185, -87.576209245)
#
#    Historical Wards 2003-2015  Zip Codes  Community Areas  Census Tracts  \
# 0                         NaN        NaN              NaN            NaN
# 1                         NaN        NaN              NaN            NaN
# 2                        22.0    14309.0             38.0           92.0
# 3                        48.0    21184.0             29.0          766.0
# 4                        32.0    22538.0             39.0          419.0
#
#    Wards  Boundaries - ZIP Codes Police Districts  Police Beats  \
# 0    NaN                     NaN              nan           NaN
# 1    NaN                     NaN              nan           NaN
# 2   36.0                    46.0             22.0          79.0
# 3   46.0                    28.0             15.0         139.0
# 4   37.0                    24.0             18.0          89.0
#
#    Primary Type Grouping Year_Month  Police Safety Score  Police Trust Score
# 0  All Other Crime Types    2007-08                  NaN                 NaN
# 1  All Other Crime Types    2002-01                  NaN                 NaN
# 2  All Other Crime Types    2023-09                62.32               63.51
# 3  All Other Crime Types    2023-08                54.24               54.21
# 4  All Other Crime Types    2023-07                63.70               69.60

# %% [markdown]
# #### Bringing in Grocery Store Data

# %%
grocery_stores = pd.read_csv('Grocery_Stores_-_2013_20231109.csv')
#Information about dataset here: https://github.com/Chicago/food-deserts

# %% [markdown]
# We could identify which areas are food deserts and create a 'Y'/'N' column for this using distance between the crime location and a grocery store. Food deserts are defined as areas in Chicago which are more than 0.5 or 1 mile from a grocery store, depending on the grocery store size. This is represented by the 'A' or 'B' buffer size. We could also represent this as the count of grocery stores within 0.5 or 1 mile.
#
# We could also simply provide the count of grocery stores for each community area, but we would probably need to control for population size using census data that can give us population numbers by Community Area. I think we could try this first, see if any correlation exists, and if one does, we can investigate further and focus in on food deserts.

# %%
grocery_stores.columns.values
# Out:
# array(['STORE NAME', 'LICENSE ID', 'ACCOUNT NUMBER', 'SQUARE FEET',
#        'BUFFER SIZE', 'ADDRESS', 'ZIP CODE', 'COMMUNITY AREA NAME',
#        'COMMUNITY AREA', 'WARD', 'CENSUS TRACT', 'CENSUS BLOCK',
#        'X COORDINATE', 'Y COORDINATE', 'LATITUDE', 'LONGITUDE',
#        'LOCATION'], dtype=object)

# %%
len(grocery_stores['COMMUNITY AREA'].unique())
# Out:
# 75

# %%
grocery_stores.groupby(['COMMUNITY AREA']).agg(Grocery_Store_Count=('STORE NAME','count')).reset_index()
# Out:
#     COMMUNITY AREA  Grocery_Store_Count
# 0                1                   13
# 1                2                   18
# 2                3                   15
# 3                4                    4
# 4                5                    6
# 5                6                    9
# 6                7                   11
# 7                8                   17
# 8                9                    1
# 9               10                    4
# 10              11                    3
# 11              12                    2
# 12              13                    2
# 13              14                   12
# 14              15                   10
# 15              16                    7
# 16              17                    9
# 17              18                    1
# 18              19                   22
# 19              20                    7
# 20              21                    6
# 21              22                   15
# 22              23                   16
# 23              24                   14
# 24              25                   14
# 25              26                    7
# 26              27                    3
# 27              28                    9
# 28              29                    4
# 29              30                   22
# 30              31                   11
# 31              32                    4
# 32              33                    2
# 33              34                    4
# 34              35                    2
# 35              37                    1
# 36              38                    4
# 37              39                    4
# 38              40                    3
# 39              41                    3
# 40              42                    5
# 41              43                    7
# 42              44                    6
# 43              45                    3
# 44              46                    5
# 45              48                    2
# 46              49                    7
# 47              50                    2
# 48              51                    4
# 49              52                    3
# 50              53                    5
# 51              54                    2
# 52              55                    3
# 53              56                    4
# 54              57                    4
# 55              58                   10
# 56              59                    4
# 57              60                    2
# 58              61                   17
# 59              62                    3
# 60              63                    5
# 61              64                    1
# 62              65                    4
# 63              66                   12
# 64              67                   11
# 65              68                    8
# 66              69                    7
# 67              70                    3
# 68              71                   11
# 69              72                    1
# 70              73                    2
# 71              74                    3
# 72              75                    7
# 73              76                    1
# 74              77                   11
